# %%
# !pip install tensorflow==2.17 opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.17 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (2.17.0)
# Requirement already satisfied: opencv-python in c:\users\pmoul\appdata\roaming\python\python312\site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow==2.17) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.4.0)
# Requirement already satisfied: packaging in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (75.6.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.45.1)
# Requirement already satisfied: rich in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (13.9.4)
# Requirement already satisfied: namex in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.0.8)
# Requirement already satisfied: optree in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pmoul\appdata\roaming\python\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pmoul\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import os
import random
import numpy as np #arrays
from matplotlib import pyplot as plt # visual facial data
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#import tensorflow dependencies
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %%
# avoid lack of memory errors to prevent computer from taking up all its time on this
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
